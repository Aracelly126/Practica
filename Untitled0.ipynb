# %% [markdown]
# <a href="https://colab.research.google.com/github/Aracelly126/Practica/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Part 1 Lineal regresion ** simple linear regresion is a method to helps us understand to relationship between two variables.

# %% [markdown]
# do I know if the dealer is offering fair value for my trade-in

# %% [markdown]
# Importar librerias

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#load file in google colab
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e15b8b37-b003-4c7b-8055-b04ecf507829" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e15b8b37-b003-4c7b-8055-b04ecf507829">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# path de la data

# %%
#path of data
df = pd.read_csv('automobileEDA.csv')
df.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# ...

# %% [markdown]
# Regresion lineal

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()
lm
# Out:
# LinearRegression()

# %% [markdown]
# how could highway-mpg help us predict car price?

# %%
X = df [['highway-mpg']]
Y = df['price']

# %% [markdown]
# Fit the linear model using highway-mpg

# %%
lm.fit(X,Y)
# Out:
# LinearRegression()

# %% [markdown]
# We can output a prediction

# %%
Yhat=lm.predict(X)
Yhat[0:5]
# Out:
# array([16236.50464347, 16236.50464347, 17058.23802179, 13771.3045085 ,
#        20345.17153508])

# %% [markdown]
# Cual es el valor del intercepto?

# %%
lm.intercept_
# Out:
# np.float64(38423.3058581574)

# %% [markdown]
# Cual es el valor de la pendiente?

# %%
lm.coef_
# Out:
# array([-821.73337832])

# %% [markdown]
# Cual es el modelo lienal estimado final que obtendremos?

# %% [markdown]
# pluggin te actual values we get

# %% [markdown]
# Question #1 a:
# create a linear regression object?

# %%
from sklearn.linear_model import LinearRegression

# Crear un objeto de regresión lineal
lm = LinearRegression()

# %% [markdown]
# Question #1
# train the model using engine-size as the independent variable and price as the dependen variable?

# %%
from sklearn.linear_model import LinearRegression

# Crear un objeto de regresión lineal
lm = LinearRegression()

# Definir las variables independiente (X) y dependiente (Y)
X = df[['engine-size']]
Y = df['price']

# Entrenar el modelo
lm.fit(X, Y)
# Out:
# LinearRegression()

# %% [markdown]
# Question 1 C
# Encontrar la pendiente y la intercepcion de el modelo

# %% [markdown]
# Pendiente

# %%
# Obtener la pendiente (coeficiente)
pendiente = lm.coef_[0]

# %% [markdown]
# Intercepcion

# %%
# Obtener la intersección (ordenada al origen)
lm.intercept_
# Out:
# np.float64(-7963.338906281042)

# %% [markdown]
# **Question #1 d)**
# cual es la ecuacion de la recta predicha? puede usar x y y
# precio = 166086 tamaño del motor -7963.34

# %%
print('y=166.86001569X -7963.33890628')
# Out:
# y=166.86001569X -7963.33890628

# %% [markdown]
# From the previous section we know that other good predictors of proce could be:
#
#
# *   horsepower
# *   curb-weight
# *   enginne-size
# *   highway-mpg

# %%
Z = df[['horsepower','curb-weight','engine-size','highway-mpg']]

# %% [markdown]
# fit the linear model using the four above-mentioned variables

# %%
lm.fit(Z,df['price'])
# Out:
# LinearRegression()

# %% [markdown]
# Cual es el valor del intercepto a

# %%
lm.intercept_
# Out:
# np.float64(-15806.62462632922)

# %% [markdown]
# Cuales son las variables coeficientes b1 b2 b3 b4

# %%
lm.coef_
# Out:
# array([53.49574423,  4.70770099, 81.53026382, 36.05748882])

# %% [markdown]
# cual es la funcion que da este ejemplo
# price -15678.7426928061 + 52.65851272xhorsepower + 4.69878948 x curb

# %%
print('Yhat=-15806.6246263292 +53.49574423 X1 +  4.70770099 X2 + 81.53026382 X3 + 36.05748882 X4')
# Out:
# Yhat=-15806.6246263292 +53.49574423 X1 +  4.70770099 X2 + 81.53026382 X3 + 36.05748882 X4

# %% [markdown]
# Question #2 a)
# create and train a multiple lineal regression model lm2 where the response variable is proce and the prediction

# %%
lm2 = LinearRegression()
lm2
# Out:
# LinearRegression()

# %%
X = df[['normalized-losses','highway-mpg']]
y = df['price']

# %%
lm2.fit(X,y)
# Out:
# LinearRegression()

# %% [markdown]
# Question #2 b
#
# Hallar el coeficiente del modelo

# %%
lm2.coef_
# Out:
# array([   1.49789586, -820.45434016])

# %%
lm2.intercept_
# Out:
# np.float64(38201.31327245728)

# %% [markdown]
# Ecuacion precio=1.4979-normalized-losses-820.4543-highwat-mpg+38201.3133

# %%
print('precio = 1.4979xnormalized-losses - 820.4543xhighway-mpg + 38201.3133')
# Out:
# precio = 1.4979xnormalized-losses - 820.4543xhighway-mpg + 38201.3133

# %% [markdown]
# Visualizacion

# %%
import seaborn as sns

# %%
width = 6
height = 5
plt.figure(figsize=(width,height))
sns.regplot(x ='highway-mpg',y='price',data=df)
plt.ylim(0,)
# Out:
# (0.0, 48163.78188755792)

# %% [markdown]
# give the regresion plots above is peak-rm

# %%
correlacion = df[['peak-rpm','highway-mpg','price']]
print(correlacion.corr())
# Out:
#              peak-rpm  highway-mpg     price
# peak-rpm     1.000000    -0.058598 -0.101616
# highway-mpg -0.058598     1.000000 -0.704692
# price       -0.101616    -0.704692  1.000000
